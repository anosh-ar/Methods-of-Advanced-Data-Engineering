# %% [markdown]
# # Data Exploration
#
# In this notebook describe your data exploration steps.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install pandas
# %pip install SQLAlchemy==1.4.46
# Out:
# Requirement already satisfied: pandas in c:\users\anosh\appdata\local\programs\python\python39\lib\site-packages (1.2.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\anosh\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.1)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\Anosh\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\anosh\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\anosh\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.22.1)
# Requirement already satisfied: six>=1.5 in c:\users\anosh\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Collecting SQLAlchemy==1.4.46Note: you may need to restart the kernel to use updated packages.
#   Downloading SQLAlchemy-1.4.46-cp39-cp39-win_amd64.whl (1.6 MB)
# WARNING: You are using pip version 21.1.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\Anosh\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\anosh\appdata\local\programs\python\python39\lib\site-packages (from SQLAlchemy==1.4.46) (1.1.2)
# Installing collected packages: SQLAlchemy
# Successfully installed SQLAlchemy-1.4.46

# %%
import torch
print(torch.__version__)
# Out:
# 1.9.1+cu102

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df = pd.read_sql_table('trainstops', 'sqlite:///data.sqlite')

# %% [markdown]
# ### Look at the first rows

# %%
df.head(30)
# Out:
#      EVA_NR  DS100                 IFOPT  \
# 0   8002551   AELB        de:02000:11943
# 1   8001944   TETN                  None
# 2   8003074    MIA                  None
# 3   8001723   HEBA                  None
# 4   8004371    KRO                  None
# 5   8010340   DSTR                  None
# 6   8001510   TDSA       de:08237:8009:2
# 7   8001966   MFOL        de:09187:90183
# 8   8002060   FFGG        de:06412:11500
# 9   8002535   EOBG         de:05962:3517
# 10  8003105   HJAH         de:03461:3106
# 11  8003297   EKIE      de:05962:2677:90
# 12  8003305  EREKK        de:05554:37195
# 13  8005169   MRAI          de:09163:201
# 14  8005933   RSFW         de:08215:1864
# 15  8011201   BFBI    de:12061:900260009
# 16  8011404    UDO      de:16065:8011404
# 17  8011605   LBGR      de:15089:8011605
# 18  8012273   LLMS      de:14713:8012273
# 19  8012797    URO      de:16065:8012797
# 20  8013241   BWAF    de:12061:900260080
# 21  8013301   DWID         de:14625:6905
# 22  8071096   WSTS    de:12068:900205749
# 23  8089201   BFBB  de:12061:900260009:3
# 24  8000001     KA         de:05334:1008
# 25  8000002     TA         de:08136:1000
# 26  8000004     HA         de:05774:7131
# 27  8000007   FALZ           de:07331:55
# 28  8000009    NAN        de:09561:11000
# 29  8000010    NAH        de:09661:99082
#
#                                      NAME  Verkehr     Laenge     Breite  \
# 0                      Hamburg Elbbrücken       RV  10.024500  53.534500
# 1                           Eutingen Nord       RV   8.753100  48.484700
# 2                         Ingolstadt Audi       RV  11.407456  48.790496
# 3                Einbeck Otto-Hahn-Straße       RV   9.892910  51.814478
# 4                   Nörvenich-Rommelsheim  nur DPN   6.547586  50.782539
# 5                 Straßgräbchen-Bernsdorf  nur DPN  14.052047  51.361469
# 6                        Dornstetten-Aach       RV   8.482910  48.473300
# 7                              Feldolling  nur DPN  11.852244  47.895336
# 8         Frankfurt(Main)-Gateway Gardens       RV   8.594495  50.056574
# 9                       Halver-Oberbrügge       RV   7.574042  51.191867
# 10                              Jaderberg  nur DPN   8.182909  53.339108
# 11                                Kierspe       RV   7.616229  51.130014
# 12                      Reken-Klein Reken  nur DPN   7.035198  51.787037
# 13                   Rosenheim Aicherpark  nur DPN  12.089467  47.851651
# 14                       Stettfeld-Weiher       RV   8.636928  49.183625
# 15           Flughafen BER - Terminal 1-2       FV  13.511950  52.364804
# 16                      Donndorf(Unstrut)  nur DPN  11.376962  51.298312
# 17                     Bernburg-Roschwitz  nur DPN  11.759300  51.781100
# 18                Leipzig Mockauer Straße       RV  12.412100  51.373800
# 19                               Roßleben  nur DPN  11.436302  51.297859
# 20                           Waßmannsdorf       RV  13.463530  52.368420
# 21                               Wiednitz  nur DPN  14.039241  51.393167
# 22                 Rheinsberg Stechlinsee  nur DPN  12.985605  53.149007
# 23  Flughafen BER - Terminal 1-2 (S-Bahn)       RV  13.511918  52.364843
# 24                             Aachen Hbf       FV   6.091499  50.767800
# 25                              Aalen Hbf       FV  10.096271  48.841013
# 26                             Altenbeken       FV   8.943319  51.766433
# 27                                  Alzey       RV   8.109749  49.750200
# 28                                Ansbach       FV  10.578239  49.298032
# 29                      Aschaffenburg Hbf       FV   9.143697  49.980557
#
#                         Betreiber_Name  Betreiber_Nr Status
# 0            DB Station und Service AG           NaN    neu
# 1            DB Station und Service AG           NaN    neu
# 2            DB Station und Service AG           NaN    neu
# 3                        Ilmebahn GmbH           NaN    neu
# 4                      Rurtalbahn GmbH           NaN    neu
# 5                                 None           NaN    neu
# 6            DB Station und Service AG           NaN    neu
# 7            DB Station und Service AG           NaN    neu
# 8            DB Station und Service AG           NaN    neu
# 9            DB Station und Service AG           NaN    neu
# 10           DB Station und Service AG           NaN    neu
# 11           DB Station und Service AG           NaN    neu
# 12           DB Station und Service AG           NaN    neu
# 13           DB Station und Service AG           NaN    neu
# 14           DB Station und Service AG           NaN    neu
# 15           DB Station und Service AG           NaN    neu
# 16     Deutsche Regionaleisenbahn GmbH           NaN    neu
# 17           DB Station und Service AG           NaN    neu
# 18           DB Station und Service AG           NaN    neu
# 19     Deutsche Regionaleisenbahn GmbH           NaN    neu
# 20           DB Station und Service AG           NaN    neu
# 21                                None           NaN    neu
# 22  Regio Infra Nord-Ost GmbH & Co. KG           NaN    neu
# 23           DB Station und Service AG           NaN    neu
# 24           DB Station und Service AG           1.0   None
# 25           DB Station und Service AG           4.0   None
# 26           DB Station und Service AG          85.0   None
# 27           DB Station und Service AG         133.0   None
# 28           DB Station und Service AG         161.0   None
# 29           DB Station und Service AG         187.0   None

# %% [markdown]
# ### Data exploration
# Print some basic information about the data. Your data exploration would continue here.

# %%
df.info()

df['Status'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6519 entries, 0 to 6518
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EVA_NR          6519 non-null   int64
#  1   DS100           6519 non-null   object
#  2   IFOPT           6512 non-null   object
#  3   NAME            6519 non-null   object
#  4   Verkehr         6519 non-null   object
#  5   Laenge          6519 non-null   float64
#  6   Breite          6519 non-null   float64
#  7   Betreiber_Name  6517 non-null   object
#  8   Betreiber_Nr    5395 non-null   float64
#  9   Status          24 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 509.4+ KB
# array(['neu', None], dtype=object)
